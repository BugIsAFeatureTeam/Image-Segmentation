# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi
import skimage
from skimage.io import imread , imshow
from skimage import color
from skimage import data
from skimage import measure
# %matplotlib inline

# %%
img = color.rgb2gray(imread('segmentation_WBC-master/Dataset 1/200.bmp'))
imshow(img)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
invert_img = 1-img
imshow(invert_img)
img
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# array([[0.97624941, 0.97568392, 0.97483569, ..., 0.97087725, 0.96974627,
#         0.96918078],
#        [0.97568392, 0.97568392, 0.97483569, ..., 0.96918078, 0.96974627,
#         0.96974627],
#        [0.97511843, 0.97568392, 0.97483569, ..., 0.94869412, 0.9635698 ,
#         0.96526627],
#        ...,
#        [0.9523698 , 0.89064902, 0.85361216, ..., 0.87185255, 0.79500314,
#         0.73812039],
#        [0.93301412, 0.87942706, 0.84519569, ..., 0.83906549, 0.8247702 ,
#         0.78331373],
#        [0.95265255, 0.89654275, 0.87776039, ..., 0.82340902, 0.83800196,
#         0.84112784]])

# %%
contours = measure.find_contours(invert_img, 0.7)
contours
# Out:
# [array([[33.50296272, 43.        ],
#         [33.2350342 , 42.        ],
#         [33.        , 41.56131768],
#         [32.686472  , 41.        ],
#         [32.        , 40.58506505],
#         [31.        , 40.09887827],
#         [30.77570955, 40.        ],
#         [30.06415341, 39.        ],
#         [30.        , 38.91617898],
#         [29.        , 38.18230787],
#         [28.        , 38.10708987],
#         [27.91156627, 38.        ],
#         [27.        , 37.26155997],
#         [26.27224642, 37.        ],
#         [26.        , 36.9177506 ],
#         [25.        , 36.84994073],
#         [24.44879788, 36.        ],
#         [24.        , 35.21118836],
#         [23.14535693, 35.        ],
#         [23.        , 34.95639596],
#         [22.87286957, 35.        ],
#         [22.        , 35.25082459],
#         [21.36443804, 36.        ],
#         [21.32882497, 37.        ],
#         [22.        , 37.830196  ],
#         [22.27188043, 38.        ],
#         [23.        , 38.98920074],
#         [23.00838282, 39.        ],
#         [23.        , 39.00636309],
#         [22.        , 39.4653149 ],
#         [21.5711956 , 40.        ],
#         [21.        , 40.47678127],
#         [20.75237447, 41.        ],
#         [20.        , 41.55516319],
#         [19.36356924, 42.        ],
#         [19.        , 42.2357106 ],
#         [18.        , 42.24013907],
#         [17.        , 42.17254517],
#         [16.47666155, 43.        ],
#         [16.59665827, 44.        ],
#         [17.        , 44.9845885 ],
#         [18.        , 44.80366734],
#         [19.        , 44.95156747],
#         [19.1778692 , 45.        ],
#         [20.        , 45.22662686],
#         [20.29727424, 45.        ],
#         [21.        , 44.3284905 ],
#         [21.30969039, 44.        ],
#         [21.70208135, 43.        ],
#         [22.        , 42.37994751],
#         [23.        , 42.104317  ],
#         [24.        , 42.42504678],
#         [25.        , 42.18157962],
#         [25.6432066 , 42.        ],
#         [26.        , 41.8064455 ],
#         [26.32412698, 42.        ],
#         [26.90110505, 43.        ],
#         [27.        , 43.04824621],
#         [27.88741132, 44.        ],
#         [28.        , 44.14576383],
#         [28.70741524, 45.        ],
#         [29.        , 45.30826176],
#         [29.58594897, 45.        ],
#         [30.        , 44.68511688],
#         [31.        , 44.33936192],
#         [32.        , 44.19314959],
#         [32.45719448, 44.        ],
#         [33.        , 43.41300308],
#         [33.50296272, 43.        ]]), array([[28.60836297, 33.        ],
#         [28.        , 32.07039934],
#         [79.30437884, 68.        ],
#         [79.86325215, 67.        ],
#         [80.        , 66.80404983],
#         [80.41028889, 66.        ],
#         [80.78912684, 65.        ],
#         [81.        , 64.46932795],
#         [81.17573298, 64.        ],
#         [81.56363584, 63.        ],
#         [81.9326242 , 62.        ],
#         [82.        , 61.77493777],
#         [82.21825632, 61.        ]]), array([[61.        , 58.14422129],
#         [60.6773282 , 58.        ],
#         [61.        , 57.76775217],
#         [61.19126417, 58.        ],
#         [61.        , 58.14422129]])]

# %%
# Display the image and plot all contours found
fig, ax = plt.subplots()
ax.imshow(invert_img, cmap=plt.cm.gray)

for n, contour in enumerate(contours):
    ax.plot(contour[:, 1], contour[:, 0], linewidth=2)
    print(contour.shape)
ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.tight_layout()
plt.savefig('c_out.png',bbox_inches='tight',pad_inches=0)
plt.show()
invert_img
# Out:
# (69, 2)
# (13, 2)
# (7, 2)
# (305, 2)
# (5, 2)
# array([[0.02375059, 0.02431608, 0.02516431, ..., 0.02912275, 0.03025373,
#         0.03081922],
#        [0.02431608, 0.02431608, 0.02516431, ..., 0.03081922, 0.03025373,
#         0.03025373],
#        [0.02488157, 0.02431608, 0.02516431, ..., 0.05130588, 0.0364302 ,
#         0.03473373],
#        ...,
#        [0.0476302 , 0.10935098, 0.14638784, ..., 0.12814745, 0.20499686,
#         0.26187961],
#        [0.06698588, 0.12057294, 0.15480431, ..., 0.16093451, 0.1752298 ,
#         0.21668627],
#        [0.04734745, 0.10345725, 0.12223961, ..., 0.17659098, 0.16199804,
#         0.15887216]])

# %%
from skimage.draw import polygon
for n, contour in enumerate(contours):
    pr = np.array([p[0] for p in contour])
    pc = np.array([p[1] for p in contour])
    row = list(map(np.uint8,contour[:,0]))
    col = list(map(np.uint8,contour[:,1]))
    rr, cc = polygon(pr,pc)
    #print(pr,',',pc)
    invert_img[rr,cc] = 255
imshow(invert_img,cmap='gray')
invert_img
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\Admin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:77: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# array([[0.02375059, 0.02431608, 0.02516431, ..., 0.02912275, 0.03025373,
#         0.03081922],
#        [0.02431608, 0.02431608, 0.02516431, ..., 0.03081922, 0.03025373,
#         0.03025373],
#        [0.02488157, 0.02431608, 0.02516431, ..., 0.05130588, 0.0364302 ,
#         0.03473373],
#        ...,
#        [0.0476302 , 0.10935098, 0.14638784, ..., 0.12814745, 0.20499686,
#         0.26187961],
#        [0.06698588, 0.12057294, 0.15480431, ..., 0.16093451, 0.1752298 ,
#         0.21668627],
#        [0.04734745, 0.10345725, 0.12223961, ..., 0.17659098, 0.16199804,
#         0.15887216]])

# %%
from skimage.filters import threshold_mean
thresh = threshold_mean(invert_img)
binary = invert_img > thresh
imshow(binary)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
from skimage.measure import label, regionprops
label_img = label(binary)
props = regionprops(label_img)

# %%
imshow(label_img)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\Admin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
# C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
for region in props:
    print(region.area)
    #print(region.convex_area)
# Out:
# 79
# 5
# 2
# 1762

# %%
len(props)
# Out:
# 4
